# %% [markdown]
# ## Aula 1 - PEGA A VISÃO

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
img = Image.open('data/cameraman/cameraman.tiff')

# %%
display(img)
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=256x256>

# %%
img = np.array(img)

# %%
plt.figure()
plt.imshow(img, 'gray')

# %%
plt.figure()
_ = plt.hist(img.flatten(), bins=256)

# %%
root = 'data/cameraman/'
img_jpeg = Image.open(root + 'cameraman.jpeg')
img = Image.open(root + 'cameraman.tiff')
img1 = Image.open(root + 'cameraman2.tiff')
img2 = Image.open(root + 'cameraman3.tiff')
img3 = Image.open(root + 'cameraman4.tiff')
img_png = Image.open(root + 'cameraman.png')
imgs = [img, img_jpeg, img_png, img1, img2, img3]
for i in imgs:
    plt.figure()
    img_ = np.array(i)
    plt.imshow(img_, 'gray')

# %%
def info(img):
    img = np.array(img)
    print("dtype:", img.dtype)
    print("shape:", img.shape)
    print("min:", img.min(),'max', img.max())

# %%
for i in imgs:
    info(i)
# Out:
# dtype: uint8
# shape: (256, 256)
# min: 7 max 253
# dtype: uint8
# shape: (256, 256)
# min: 0 max 255
# dtype: uint8
# shape: (256, 256)
# min: 7 max 253
# dtype: uint8
# shape: (256, 256, 3)
# min: 7 max 253
# dtype: uint8
# shape: (256, 256, 4)
# min: 7 max 255
# dtype: uint16
# shape: (256, 256)
# min: 1799 max 65021

# %% [markdown]
# ## Função display

# %%
from IPython.display import display
from IPython.display import clear_output
text = "olá mundo"
display(text)
# Out:
# 'olá mundo'

# %%
x = []
for i in range(1000):
    x.append(i)
    fig, ax = plt.subplots()
    ax.scatter(x, x)
    plt.close()
    clear_output(wait = True)    
    display(fig)
